# %%
import nltk
from nltk import word_tokenize

# %%
def printSomeIterable(someIter):
    for w in someIter:
        print(w)

# %%
with open("shortDoc", "r") as f:
    contents = f.read()

# %%
#print(contents)
docWords = word_tokenize(contents)
vocab = set(docWords)
bg = nltk.bigrams(docWords)

# %%
#printSomeIterable(bg)

# %%
bgList = list(bg)
#print(bgList)
len(bgList)
# Out:
# 458

# %%
st = ("HIDDEN", "COBRA")
if st in bg:
    print("Found")

# %%
printSomeIterable(bg)

# %%
#print(bgList)
count = 0
for tp in bgList:
    print("Testing Tuple: " + str(tp))
    if st in tp:
       count += 1
# Out:
# Testing Tuple: ('Malware', 'Analysis')
# Testing Tuple: ('Analysis', 'Report')
# Testing Tuple: ('Report', '(')
# Testing Tuple: ('(', 'MAR')
# Testing Tuple: ('MAR', ')')
# Testing Tuple: (')', '-')
# Testing Tuple: ('-', '10135536-F')
# Testing Tuple: ('10135536-F', 'TLP')
# Testing Tuple: ('TLP', ':')
# Testing Tuple: (':', 'WHITE')
# Testing Tuple: ('WHITE', 'Malware')
# Testing Tuple: ('Malware', 'Analysis')
# Testing Tuple: ('Analysis', 'Report')
# Testing Tuple: ('Report', '(')
# Testing Tuple: ('(', 'MAR')
# Testing Tuple: ('MAR', ')')
# Testing Tuple: (')', '-')
# Testing Tuple: ('-', '10135536-F')
# Testing Tuple: ('10135536-F', '2018-02-05')
# Testing Tuple: ('2018-02-05', 'Notification')
# Testing Tuple: ('Notification', 'This')
# Testing Tuple: ('This', 'report')
# Testing Tuple: ('report', 'is')
# Testing Tuple: ('is', 'provided')
# Testing Tuple: ('provided', '\\')
# Testing Tuple: ('\\', "''")
# Testing Tuple: ("''", 'as')
# Testing Tuple: ('as', 'is\\')
# Testing Tuple: ('is\\', "''")
# Testing Tuple: ("''", 'for')
# Testing Tuple: ('for', 'informational')
# Testing Tuple: ('informational', 'purposes')
# Testing Tuple: ('purposes', 'only')
# Testing Tuple: ('only', '.')
# Testing Tuple: ('.', 'The')
# Testing Tuple: ('The', 'Department')
# Testing Tuple: ('Department', 'of')
# Testing Tuple: ('of', 'Homeland')
# Testing Tuple: ('Homeland', 'Security')
# Testing Tuple: ('Security', '(')
# Testing Tuple: ('(', 'DHS')
# Testing Tuple: ('DHS', ')')
# Testing Tuple: (')', 'does')
# Testing Tuple: ('does', 'not')
# Testing Tuple: ('not', 'provide')
# Testing Tuple: ('provide', 'any')
# Testing Tuple: ('any', 'warranties')
# Testing Tuple: ('warranties', 'of')
# Testing Tuple: ('of', 'any')
# Testing Tuple: ('any', 'kind')
# Testing Tuple: ('kind', 'regarding')
# Testing Tuple: ('regarding', 'any')
# Testing Tuple: ('any', 'information')
# Testing Tuple: ('information', 'contained')
# Testing Tuple: ('contained', 'within')
# Testing Tuple: ('within', '.')
# Testing Tuple: ('.', 'The')
# Testing Tuple: ('The', 'DHS')
# Testing Tuple: ('DHS', 'does')
# Testing Tuple: ('does', 'not')
# Testing Tuple: ('not', 'endorse')
# Testing Tuple: ('endorse', 'any')
# Testing Tuple: ('any', 'commercial')
# Testing Tuple: ('commercial', 'product')
# Testing Tuple: ('product', 'or')
# Testing Tuple: ('or', 'service')
# Testing Tuple: ('service', ',')
# Testing Tuple: (',', 'referenced')
# Testing Tuple: ('referenced', 'in')
# Testing Tuple: ('in', 'this')
# Testing Tuple: ('this', 'bulletin')
# Testing Tuple: ('bulletin', 'or')
# Testing Tuple: ('or', 'otherwise')
# Testing Tuple: ('otherwise', '.')
# Testing Tuple: ('.', 'This')
# Testing Tuple: ('This', 'document')
# Testing Tuple: ('document', 'is')
# Testing Tuple: ('is', 'marked')
# Testing Tuple: ('marked', 'TLP')
# Testing Tuple: ('TLP', ':')
# Testing Tuple: (':', 'WHITE')
# Testing Tuple: ('WHITE', '.')
# Testing Tuple: ('.', 'Disclosure')
# Testing Tuple: ('Disclosure', 'is')
# Testing Tuple: ('is', 'not')
# Testing Tuple: ('not', 'limited')
# Testing Tuple: ('limited', '.')
# Testing Tuple: ('.', 'Sources')
# Testing Tuple: ('Sources', 'may')
# Testing Tuple: ('may', 'use')
# Testing Tuple: ('use', 'TLP')
# Testing Tuple: ('TLP', ':')
# Testing Tuple: (':', 'WHITE')
# Testing Tuple: ('WHITE', 'when')
# Testing Tuple: ('when', 'information')
# Testing Tuple: ('information', 'carries')
# Testing Tuple: ('carries', 'minimal')
# Testing Tuple: ('minimal', 'or')
# Testing Tuple: ('or', 'no')
# Testing Tuple: ('no', 'foreseeable')
# Testing Tuple: ('foreseeable', 'risk')
# Testing Tuple: ('risk', 'of')
# Testing Tuple: ('of', 'misuse')
# Testing Tuple: ('misuse', ',')
# Testing Tuple: (',', 'in')
# Testing Tuple: ('in', 'accordance')
# Testing Tuple: ('accordance', 'with')
# Testing Tuple: ('with', 'applicable')
# Testing Tuple: ('applicable', 'rules')
# Testing Tuple: ('rules', 'and')
# Testing Tuple: ('and', 'procedures')
# Testing Tuple: ('procedures', 'for')
# Testing Tuple: ('for', 'public')
# Testing Tuple: ('public', 'release')
# Testing Tuple: ('release', '.')
# Testing Tuple: ('.', 'Subject')
# Testing Tuple: ('Subject', 'to')
# Testing Tuple: ('to', 'standard')
# Testing Tuple: ('standard', 'copyright')
# Testing Tuple: ('copyright', 'rules')
# Testing Tuple: ('rules', ',')
# Testing Tuple: (',', 'TLP')
# Testing Tuple: ('TLP', ':')
# Testing Tuple: (':', 'WHITE')
# Testing Tuple: ('WHITE', 'information')
# Testing Tuple: ('information', 'may')
# Testing Tuple: ('may', 'be')
# Testing Tuple: ('be', 'distr')
# Testing Tuple: ('distr', 'buted')
# Testing Tuple: ('buted', 'without')
# Testing Tuple: ('without', 'restriction')
# Testing Tuple: ('restriction', '.')
# Testing Tuple: ('.', 'For')
# Testing Tuple: ('For', 'more')
# Testing Tuple: ('more', 'information')
# Testing Tuple: ('information', 'on')
# Testing Tuple: ('on', 'the')
# Testing Tuple: ('the', 'Traffic')
# Testing Tuple: ('Traffic', 'Light')
# Testing Tuple: ('Light', 'Protocol')
# Testing Tuple: ('Protocol', ',')
# Testing Tuple: (',', 'see')
# Testing Tuple: ('see', 'http')
# Testing Tuple: ('http', ':')
# Testing Tuple: (':', '//www.us-cert.gov')
# Testing Tuple: ('//www.us-cert.gov', '/tlp/')
# Testing Tuple: ('/tlp/', '.')
# Testing Tuple: ('.', 'Summary')
# Testing Tuple: ('Summary', 'Description')
# Testing Tuple: ('Description', 'This')
# Testing Tuple: ('This', 'Malware')
# Testing Tuple: ('Malware', 'Analysis')
# Testing Tuple: ('Analysis', 'Report')
# Testing Tuple: ('Report', '(')
# Testing Tuple: ('(', 'MAR')
# Testing Tuple: ('MAR', ')')
# Testing Tuple: (')', 'is')
# Testing Tuple: ('is', 'the')
# Testing Tuple: ('the', 'result')
# Testing Tuple: ('result', 'of')
# Testing Tuple: ('of', 'analytic')
# Testing Tuple: ('analytic', 'efforts')
# Testing Tuple: ('efforts', 'between')
# Testing Tuple: ('between', 'the')
# Testing Tuple: ('the', 'Department')
# Testing Tuple: ('Department', 'of')
# Testing Tuple: ('of', 'Homeland')
# Testing Tuple: ('Homeland', 'Security')
# Testing Tuple: ('Security', '(')
# Testing Tuple: ('(', 'DHS')
# Testing Tuple: ('DHS', ')')
# Testing Tuple: (')', 'and')
# Testing Tuple: ('and', 'the')
# Testing Tuple: ('the', 'Federal')
# Testing Tuple: ('Federal', 'Bureau')
# Testing Tuple: ('Bureau', 'of')
# Testing Tuple: ('of', 'Investigation')
# Testing Tuple: ('Investigation', '(')
# Testing Tuple: ('(', 'FBI')
# Testing Tuple: ('FBI', ')')
# Testing Tuple: (')', '.')
# Testing Tuple: ('.', 'Working')
# Testing Tuple: ('Working', 'with')
# Testing Tuple: ('with', 'U.S.')
# Testing Tuple: ('U.S.', 'Government')
# Testing Tuple: ('Government', 'partners')
# Testing Tuple: ('partners', ',')
# Testing Tuple: (',', 'DHS')
# Testing Tuple: ('DHS', 'and')
# Testing Tuple: ('and', 'FBI')
# Testing Tuple: ('FBI', 'identified')
# Testing Tuple: ('identified', 'Trojan')
# Testing Tuple: ('Trojan', 'malware')
# Testing Tuple: ('malware', 'variants')
# Testing Tuple: ('variants', 'used')
# Testing Tuple: ('used', 'by')
# Testing Tuple: ('by', 'the')
# Testing Tuple: ('the', 'North')
# Testing Tuple: ('North', 'Korean')
# Testing Tuple: ('Korean', 'government')
# Testing Tuple: ('government', '–')
# Testing Tuple: ('–', 'commonly')
# Testing Tuple: ('commonly', 'known')
# Testing Tuple: ('known', 'as')
# Testing Tuple: ('as', 'HARDRAIN')
# Testing Tuple: ('HARDRAIN', '.')
# Testing Tuple: ('.', 'The')
# Testing Tuple: ('The', 'U.S.')
# Testing Tuple: ('U.S.', 'Government')
# Testing Tuple: ('Government', 'refers')
# Testing Tuple: ('refers', 'to')
# Testing Tuple: ('to', 'malicious')
# Testing Tuple: ('malicious', 'cyber')
# Testing Tuple: ('cyber', 'activity')
# Testing Tuple: ('activity', 'by')
# Testing Tuple: ('by', 'the')
# Testing Tuple: ('the', 'North')
# Testing Tuple: ('North', 'Korean')
# Testing Tuple: ('Korean', 'government')
# Testing Tuple: ('government', 'as')
# Testing Tuple: ('as', 'HIDDEN')
# Testing Tuple: ('HIDDEN', 'COBRA')
# Testing Tuple: ('COBRA', '.')
# Testing Tuple: ('.', 'For')
# Testing Tuple: ('For', 'more')
# Testing Tuple: ('more', 'information')
# Testing Tuple: ('information', 'on')
# Testing Tuple: ('on', 'HIDDEN')
# Testing Tuple: ('HIDDEN', 'COBRA')
# Testing Tuple: ('COBRA', 'activity')
# Testing Tuple: ('activity', ',')
# Testing Tuple: (',', 'visit')
# Testing Tuple: ('visit', 'https')
# Testing Tuple: ('https', '[')
# Testing Tuple: ('[', ':')
# Testing Tuple: (':', ']')
# Testing Tuple: (']', '//www')
# Testing Tuple: ('//www', '[')
# Testing Tuple: ('[', '.')
# Testing Tuple: ('.', ']')
# Testing Tuple: (']', 'us-cert.gov')
# Testing Tuple: ('us-cert.gov', '/hiddencobra')
# Testing Tuple: ('/hiddencobra', '.')
# Testing Tuple: ('.', 'FBI')
# Testing Tuple: ('FBI', 'has')
# Testing Tuple: ('has', 'high')
# Testing Tuple: ('high', 'confidence')
# Testing Tuple: ('confidence', 'that')
# Testing Tuple: ('that', 'HIDDEN')
# Testing Tuple: ('HIDDEN', 'COBRA')
# Testing Tuple: ('COBRA', 'actors')
# Testing Tuple: ('actors', 'are')
# Testing Tuple: ('are', 'using')
# Testing Tuple: ('using', 'malware')
# Testing Tuple: ('malware', 'variants')
# Testing Tuple: ('variants', 'in')
# Testing Tuple: ('in', 'conjunction')
# Testing Tuple: ('conjunction', 'with')
# Testing Tuple: ('with', 'proxy')
# Testing Tuple: ('proxy', 'servers')
# Testing Tuple: ('servers', 'to')
# Testing Tuple: ('to', 'maintain')
# Testing Tuple: ('maintain', 'a')
# Testing Tuple: ('a', 'presence')
# Testing Tuple: ('presence', 'on')
# Testing Tuple: ('on', 'victim')
# Testing Tuple: ('victim', 'networks')
# Testing Tuple: ('networks', 'and')
# Testing Tuple: ('and', 'to')
# Testing Tuple: ('to', 'further')
# Testing Tuple: ('further', 'network')
# Testing Tuple: ('network', 'exploitation')
# Testing Tuple: ('exploitation', '.')
# Testing Tuple: ('.', 'DHS')
# Testing Tuple: ('DHS', 'and')
# Testing Tuple: ('and', 'FBI')
# Testing Tuple: ('FBI', 'are')
# Testing Tuple: ('are', 'distributing')
# Testing Tuple: ('distributing', 'this')
# Testing Tuple: ('this', 'MAR')
# Testing Tuple: ('MAR', 'to')
# Testing Tuple: ('to', 'enable')
# Testing Tuple: ('enable', 'network')
# Testing Tuple: ('network', 'defense')
# Testing Tuple: ('defense', 'and')
# Testing Tuple: ('and', 'reduce')
# Testing Tuple: ('reduce', 'exposure')
# Testing Tuple: ('exposure', 'to')
# Testing Tuple: ('to', 'North')
# Testing Tuple: ('North', 'Korean')
# Testing Tuple: ('Korean', 'government')
# Testing Tuple: ('government', 'malicious')
# Testing Tuple: ('malicious', 'cyber')
# Testing Tuple: ('cyber', 'activity')
# Testing Tuple: ('activity', '.')
# Testing Tuple: ('.', 'This')
# Testing Tuple: ('This', 'MAR')
# Testing Tuple: ('MAR', 'includes')
# Testing Tuple: ('includes', 'malware')
# Testing Tuple: ('malware', 'descriptions')
# Testing Tuple: ('descriptions', 'related')
# Testing Tuple: ('related', 'to')
# Testing Tuple: ('to', 'HIDDEN')
# Testing Tuple: ('HIDDEN', 'COBRA')
# Testing Tuple: ('COBRA', ',')
# Testing Tuple: (',', 'suggested')
# Testing Tuple: ('suggested', 'response')
# Testing Tuple: ('response', 'actions')
# Testing Tuple: ('actions', 'and')
# Testing Tuple: ('and', 'recommended')
# Testing Tuple: ('recommended', 'mitigation')
# Testing Tuple: ('mitigation', 'techniques')
# Testing Tuple: ('techniques', '.')
# Testing Tuple: ('.', 'Users')
# Testing Tuple: ('Users', 'or')
# Testing Tuple: ('or', 'administrators')
# Testing Tuple: ('administrators', 'should')
# Testing Tuple: ('should', 'flag')
# Testing Tuple: ('flag', 'activity')
# Testing Tuple: ('activity', 'associated')
# Testing Tuple: ('associated', 'with')
# Testing Tuple: ('with', 'the')
# Testing Tuple: ('the', 'malware')
# Testing Tuple: ('malware', ',')
# Testing Tuple: (',', 'report')
# Testing Tuple: ('report', 'the')
# Testing Tuple: ('the', 'activity')
# Testing Tuple: ('activity', 'to')
# Testing Tuple: ('to', 'the')
# Testing Tuple: ('the', 'DHS')
# Testing Tuple: ('DHS', 'National')
# Testing Tuple: ('National', 'Cybersecurity')
# Testing Tuple: ('Cybersecurity', 'and')
# Testing Tuple: ('and', 'Communications')
# Testing Tuple: ('Communications', 'Integration')
# Testing Tuple: ('Integration', 'Center')
# Testing Tuple: ('Center', '(')
# Testing Tuple: ('(', 'NCCIC')
# Testing Tuple: ('NCCIC', ')')
# Testing Tuple: (')', 'or')
# Testing Tuple: ('or', 'the')
# Testing Tuple: ('the', 'FBI')
# Testing Tuple: ('FBI', 'Cyber')
# Testing Tuple: ('Cyber', 'Watch')
# Testing Tuple: ('Watch', '(')
# Testing Tuple: ('(', 'CyWatch')
# Testing Tuple: ('CyWatch', ')')
# Testing Tuple: (')', ',')
# Testing Tuple: (',', 'and')
# Testing Tuple: ('and', 'give')
# Testing Tuple: ('give', 'the')
# Testing Tuple: ('the', 'activity')
# Testing Tuple: ('activity', 'the')
# Testing Tuple: ('the', 'highest')
# Testing Tuple: ('highest', 'priority')
# Testing Tuple: ('priority', 'for')
# Testing Tuple: ('for', 'enhanced')
# Testing Tuple: ('enhanced', 'mitigation')
# Testing Tuple: ('mitigation', '.')
# Testing Tuple: ('.', 'This')
# Testing Tuple: ('This', 'report')
# Testing Tuple: ('report', 'provides')
# Testing Tuple: ('provides', 'analysis')
# Testing Tuple: ('analysis', 'of')
# Testing Tuple: ('of', 'three')
# Testing Tuple: ('three', '(')
# Testing Tuple: ('(', '3')
# Testing Tuple: ('3', ')')
# Testing Tuple: (')', 'malicious')
# Testing Tuple: ('malicious', 'executable')
# Testing Tuple: ('executable', 'files')
# Testing Tuple: ('files', '.')
# Testing Tuple: ('.', 'The')
# Testing Tuple: ('The', 'first')
# Testing Tuple: ('first', 'two')
# Testing Tuple: ('two', '(')
# Testing Tuple: ('(', '2')
# Testing Tuple: ('2', ')')
# Testing Tuple: (')', 'files')
# Testing Tuple: ('files', 'are')
# Testing Tuple: ('are', '32-bit')
# Testing Tuple: ('32-bit', 'Windows')
# Testing Tuple: ('Windows', 'executables')
# Testing Tuple: ('executables', 'that')
# Testing Tuple: ('that', 'function')
# Testing Tuple: ('function', 'as')
# Testing Tuple: ('as', 'Proxy')
# Testing Tuple: ('Proxy', 'servers')
# Testing Tuple: ('servers', 'and')
# Testing Tuple: ('and', 'implement')
# Testing Tuple: ('implement', 'a')
# Testing Tuple: ('a', '\\')
# Testing Tuple: ('\\', "''")
# Testing Tuple: ("''", 'Fake')
# Testing Tuple: ('Fake', 'TLS\\')
# Testing Tuple: ('TLS\\', "''")
# Testing Tuple: ("''", 'method')
# Testing Tuple: ('method', 'similar')
# Testing Tuple: ('similar', 'to')
# Testing Tuple: ('to', 'the')
# Testing Tuple: ('the', 'behavior')
# Testing Tuple: ('behavior', 'described')
# Testing Tuple: ('described', 'in')
# Testing Tuple: ('in', 'a')
# Testing Tuple: ('a', 'previously')
# Testing Tuple: ('previously', 'published')
# Testing Tuple: ('published', 'NCCIC')
# Testing Tuple: ('NCCIC', 'report')
# Testing Tuple: ('report', ',')
# Testing Tuple: (',', 'MAR-10135536-B')
# Testing Tuple: ('MAR-10135536-B', '.')
# Testing Tuple: ('.', 'The')
# Testing Tuple: ('The', 'third')
# Testing Tuple: ('third', 'file')
# Testing Tuple: ('file', 'is')
# Testing Tuple: ('is', 'an')
# Testing Tuple: ('an', 'Executable')
# Testing Tuple: ('Executable', 'Linkable')
# Testing Tuple: ('Linkable', 'Format')
# Testing Tuple: ('Format', '(')
# Testing Tuple: ('(', 'ELF')
# Testing Tuple: ('ELF', ')')
# Testing Tuple: (')', 'file')
# Testing Tuple: ('file', 'designed')
# Testing Tuple: ('designed', 'to')
# Testing Tuple: ('to', 'run')
# Testing Tuple: ('run', 'on')
# Testing Tuple: ('on', 'Android')
# Testing Tuple: ('Android', 'platforms')
# Testing Tuple: ('platforms', 'as')
# Testing Tuple: ('as', 'a')
# Testing Tuple: ('a', 'fully')
# Testing Tuple: ('fully', 'functioning')
# Testing Tuple: ('functioning', 'Remote')
# Testing Tuple: ('Remote', 'Access')
# Testing Tuple: ('Access', 'Tool')
# Testing Tuple: ('Tool', '(')
# Testing Tuple: ('(', 'RAT')
# Testing Tuple: ('RAT', ')')
# Testing Tuple: (')', '.')
# Testing Tuple: ('.', 'Files')
# Testing Tuple: ('Files', 'Processed')
# Testing Tuple: ('Processed', '3')
# Testing Tuple: ('3', '3dae0dc356c2b217a452b477c4b1db06')
# Testing Tuple: ('3dae0dc356c2b217a452b477c4b1db06', '(')
# Testing Tuple: ('(', '3DAE0DC356C2B217A452B477C4B1DB06')
# Testing Tuple: ('3DAE0DC356C2B217A452B477C4B1DB06', ')')
# Testing Tuple: (')', '746cfecfd348b0751ce36c8f504d2c76')
# Testing Tuple: ('746cfecfd348b0751ce36c8f504d2c76', '(')
# Testing Tuple: ('(', '746CFECFD348B0751CE36C8F504D2C76')
# Testing Tuple: ('746CFECFD348B0751CE36C8F504D2C76', ')')
# Testing Tuple: (')', '9ce9a0b3876aacbf0e8023c97fd0a21d')
# Testing Tuple: ('9ce9a0b3876aacbf0e8023c97fd0a21d', '(')
# Testing Tuple: ('(', '9CE9A0B3876AACBF0E8023C97FD0A21D')
# Testing Tuple: ('9CE9A0B3876AACBF0E8023C97FD0A21D', ')')
# Testing Tuple: (')', 'TLP')
# Testing Tuple: ('TLP', ':')
# Testing Tuple: (':', 'WHITE')

# %%
print("Found: + {} instances of {} ".format(count, st))
# Out:
# Found: + 0 instances of ('HIDDEN', 'COBRA')

# %%
print(st)
# Out:
# ('HIDDEN', 'COBRA')
